# %% [markdown]
# ## Reading Image

# %% [markdown]
# #### Reading using PIL

# %%
import numpy as np
from PIL import Image

# %%
img = Image.open("../Resources/image_properties/image.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=620x1219>

# %%
arr = np.array(img)
# arr
arr.shape
# Out:
# (1219, 620, 3)

# %%
img.save('test.jpg')
img.show()

# %% [markdown]
# #### Reading using OpenCV

# %%
import cv2

# %%
img1 = cv2.imread("../Resources/image_properties/image.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=620x1219>

# %%
img1.shape
# Out:
# (1219, 620, 3)

# %%
cv2.imwrite('test1.jpg', img1)
# Out:
# True

# %%
# cv2.imshow("image1.jpg", img1)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
print(f"Shape of img:{img1.shape}")
# Out:
# Shape of img:(1219, 620, 3)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img1)
